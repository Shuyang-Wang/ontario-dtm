# %%
import os
import csv
from osgeo import gdal
import re

# Base directory to search for raster files
base_dir = '/Volumes/Expansion 1/DTM_UNZIP/'

# Output CSV file
output_csv = "raster_metadata.csv"

def parse_projection(projection_str):
    """Extract key projection parameters from a WKT projection string."""
    projection_dict = {}
    # Extract the authority code (EPSG code)
    epsg_match = re.search(r'AUTHORITY\["EPSG","(\d+)"\]', projection_str)
    if epsg_match:
        projection_dict['EPSG Code'] = epsg_match.group(1)

    # Extract the projection name
    proj_match = re.search(r'PROJECTION\["([^\]]+)"\]', projection_str)
    if proj_match:
        projection_dict['Projection'] = proj_match.group(1)

    # Extract the spheroid information
    spheroid_match = re.search(r'SPHEROID\["([^"]+)",([\d.]+),([\d.]+)\]', projection_str)
    if spheroid_match:
        projection_dict['Spheroid'] = spheroid_match.group(1)
        projection_dict['Semi-major Axis'] = spheroid_match.group(2)
        projection_dict['Inverse Flattening'] = spheroid_match.group(3)

    # Extract the datum information
    datum_match = re.search(r'DATUM\["([^"]+)"\]', projection_str)
    if datum_match:
        projection_dict['Datum'] = datum_match.group(1)

    # Extract unit of measure
    unit_match = re.search(r'UNIT\["([^"]+)",([\d.]+)\]', projection_str)
    if unit_match:
        projection_dict['Unit'] = unit_match.group(1)
        projection_dict['Unit Conversion Factor'] = unit_match.group(2)

    return projection_dict

def save_raster_metadata_to_csv(metadata, csv_file):
    """Save metadata as rows in a CSV file."""
    # Define a set of field names that includes all possible fields
    fieldnames = [
        "File Path", 
        "EPSG Code", 
        "Projection", 
        "Spheroid", 
        "Semi-major Axis", 
        "Inverse Flattening", 
        "Datum", 
        "Unit", 
        "Unit Conversion Factor",
        "GeoTransform Top Left X", 
        "GeoTransform Pixel Size X", 
        "GeoTransform Rotation X", 
        "GeoTransform Top Left Y", 
        "GeoTransform Rotation Y", 
        "GeoTransform Pixel Size Y"
    ]

    # Open the CSV file and write the header and data
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        for data in metadata:
            writer.writerow(data)

def get_raster_metadata(file_path):
    """Extract spatial reference metadata from a raster file and return as a dictionary."""
    dataset = gdal.Open(file_path)
    if dataset is None:
        print(f"Failed to open {file_path}")
        return None

    projection = dataset.GetProjection()
    geo_transform = dataset.GetGeoTransform()

    # Parse projection information
    projection_info = parse_projection(projection)

    # Add geotransform values to the metadata
    metadata = {
        "File Path": file_path,
        "GeoTransform Top Left X": geo_transform[0],
        "GeoTransform Pixel Size X": geo_transform[1],
        "GeoTransform Rotation X": geo_transform[2],
        "GeoTransform Top Left Y": geo_transform[3],
        "GeoTransform Rotation Y": geo_transform[4],
        "GeoTransform Pixel Size Y": geo_transform[5]
    }

    # Merge parsed projection info with geotransform data
    metadata.update(projection_info)
    return metadata

def process_first_raster_in_folder(folder, metadata_list):
    """Search for the first .img or .tif file in the folder, extract metadata, and append to list."""
    found_file = False
    print(f"Checking folder: {folder}")
    
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith((".img", ".tif")):  # Check for both .img and .tif files
                file_path = os.path.join(root, file)
                print(f"Found file: {file_path}")
                metadata = get_raster_metadata(file_path)
                if metadata:
                    metadata_list.append(metadata)
                found_file = True
                return  # Stop after processing the first .img or .tif file
    
    if not found_file:
        print(f"No .img or .tif file found in {folder}\n")

# Automatically get all folders under the base directory
def get_all_subfolders(base_directory):
    """Return a list of all subdirectories in the given base directory."""
    return [os.path.join(base_directory, d) for d in os.listdir(base_directory) if os.path.isdir(os.path.join(base_directory, d))]

# List to hold metadata for each file
raster_metadata_list = []

# Get all subfolders under the base directory
folders = get_all_subfolders(base_dir)

# Loop through each folder and process only the first .img or .tif file
for folder in folders:
    process_first_raster_in_folder(folder, raster_metadata_list)

# Save all metadata to a CSV file
if raster_metadata_list:
    save_raster_metadata_to_csv(raster_metadata_list, output_csv)
    print(f"Metadata saved to {output_csv}")
else:
    print("No metadata to save.")
# Out:
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-A/1km182830488802022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-B/1km183050486602022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-C/1km183190485802022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-D/1km183290485602022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-E/1km182800489802022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-P
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-P/1km182700496302022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-F/1km183010488902022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-G
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-G/1km183190489302022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-H
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-H/1km182810492602022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-I
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-I/1km183030490902022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-J
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-J/1km183220490902022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-K
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-K/1km183400489302022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-L
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-L/1km182750494402022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-M
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-M/1km182980492802022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-N
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-N/1km183180492802022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-O
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-O/1km183380492802022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-Q
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-Q/1km182910494602022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-R
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-R/1km183100494602022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-S
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-S/1km182500498502022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-T
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-T/1km182700496502022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-U
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-U/1km182830496502022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-V
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-V/1km183040496502022LBELLEVILLE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/CLOCA_Lidar_DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/CLOCA_Lidar_DTM-A/1km176530487602018LCLOCA_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-01
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-01/1km183330488202022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-02
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-02/1km183700489702022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-03
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-03/1km183520493302022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-04
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-04/1km183820491002022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-05
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-05/1km184100491002021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-06
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-06/1km183330495502021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-07
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-07/1km183650493402022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-08
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-08/1km183900494302022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-09
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-09/1km184250493702022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-10
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-10/1km183130497702021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-11
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-11/1km183480495802022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-12
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-12/1km183710495802022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-13
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-13/1km183950495802022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-14
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-14/1km184220495802022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-15
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-15/1km184500495802022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-16
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-16/1km183150498102021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-17
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-17/1km183450498102021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-18
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-18/1km183620498102021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-19
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-19/1km183800498102022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-20
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-20/1km183800499902021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-21
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-21/1km184020498102022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-22
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-22/1km184360498102022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-23
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-23/1km184670501302021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-24
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-24/1km184960499302021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-25
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-25/1km185190498302021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-26
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-26/1km184660501602021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-27
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-27/1km185050504602021LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-28
# Found file: /Volumes/Expansion 1/DTM_UNZIP/EasternOntario-DTM-28/1km185260501302022LEASTERNONTARIO_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA-Brampton-LidarDTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA-Brampton-LidarDTM-A/1km175890483602015LBrampton_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA-Halton-LidarDTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA-Halton-LidarDTM-A/1km175690480902018LHalton_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA-Halton-LidarDTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA-Halton-LidarDTM-B/1km175920479202018LHalton_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA-Halton-LidarDTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA-Halton-LidarDTM-C/1km175710481402018LHalton_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA-Halton-LidarDTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA-Halton-LidarDTM-D/1km175900481402018LHalton_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA-Milton-LidarDTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA-Milton-LidarDTM-A/1km175620484902017LMilton_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA-Peel-LidarDTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA-Peel-LidarDTM-A/1km175720485302016LPeel_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA-Peel-LidarDTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA-Peel-LidarDTM-B/1km175660485902016LPeel_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2014-LidarDTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2014-LidarDTM-A/1km175840486502014LGTA2014_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2014-LidarDTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2014-LidarDTM-B/1km176020483902014LGTA2014_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2014-LidarDTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2014-LidarDTM-C/1km176140484702014LGTA2014_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2014-LidarDTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2014-LidarDTM-D/1km176300485702014LGTA2014_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-A/1km175780486802015LGTA2015_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-B/1km175930483102015LGTA2015_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-C/1km176130481602015LGTA2015_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-D/1km176240483102015LGTA2015_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-E/1km176350483002015LGTA2015_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/GTA2015-LidarDTM-F/1km176470484502015LGTA2015_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-A/1km175650480502021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-B/1km175840477802021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-C/1km176010477302021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-D/1km176210477302021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-E/1km176430477302021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-F/1km175880477002021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-G
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-G/1km176090475502021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-H
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-H/1km176250475802021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-I
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-I/1km176450475802021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-J
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-J/1km176220474402021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-K
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Hamilton-Niagara-DTM-K/1km176470474702021LNIAGARA_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-01
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-01/1km174400484302022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-02
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-02/1km174640483102022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-03
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-03/1km174860483002022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-04
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-04/1km175010481802022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-05
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-05/1km174410485302022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-06
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-06/1km174650485302022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-07
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-07/1km174880485302022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-08
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-08/1km175110485302022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-09
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-09/1km174390487802022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-10
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-10/1km174670487402022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-11
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-11/1km174900487402022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-12
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-12/1km175130487402022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-13
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-13/1km175320487402022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-14
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-14/1km174500489502022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-15
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-15/1km174760489502022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-16
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-16/1km174980489502022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-17
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-17/1km175180489502022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-18
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-18/1km175390489502022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-19
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-19/1km175570488102022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-20
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-20/1km175570489402022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-21
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-21/1km174600491702022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-22
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-22/1km174930491702022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-23
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-23/1km175170491702022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-24
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-24/1km175440493302022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-25
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-25/1km174690496302022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-26
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-26/1km174900493702022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-27
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-27/1km175780492302022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-28
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-28/1km175960491802022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-29
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-29/1km175590496402022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-30
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-30/1km175890494402022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-31
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-31/1km176040494402022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-32
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-32/1km176180494402022LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-33
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-33/1km174770496902023LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-34
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-34/1km174940495802023LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-35
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-35/1km175240493802023LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-36
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-36/1km175740492002023LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-37
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-37/1km175770490702023LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-38
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-38/1km175800489402023LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-39
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-39/1km175830488002023LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-40
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-40/1km174550499502023LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-41
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronGeorgianBay-DTM-41/1km174380501702023LHURONGEORGIANBAY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/HuronShores-DTM-01
# Found file: /Volumes/Expansion 1/DTM_UNZIP/HuronShores-DTM-01/HuronShores-DTM-01/1km172950512702021LHURONSHORES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-01
# Found file: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-01/1km176560487702023LKAWARTHALAKES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-02
# Found file: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-02/1km176760488002023LKAWARTHALAKES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-03
# Found file: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-03/1km176610490102023LKAWARTHALAKES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-04
# Found file: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-04/1km176830490102023LKAWARTHALAKES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-05
# Found file: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-05/1km176490493702023LKAWARTHALAKES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-06
# Found file: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-06/1km176780492102023LKAWARTHALAKES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-07
# Found file: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-07/1km176410496102023LKAWARTHALAKES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-08
# Found file: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-08/1km176590494002023LKAWARTHALAKES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-09
# Found file: /Volumes/Expansion 1/DTM_UNZIP/KawarthaLakes-DTM-09/1km176720494002023LKAWARTHALAKES_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-A/A/1km182770487602008LEAP.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-B/B/1km182900487502008LEAP.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-C/C/1km183320488102008LEAP.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-D/D/1km183620491302008LEAP.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-E/E/1km184020490702008LEAP.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-A/Cochrane_A/1km172830550502016LCOCHRANE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-B/Cochrane_B/1km173260549102016LCOCHRANE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-C/1km173620547902017LCOCHRANE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-D/Cochrane_D/1km173970546502016LCOCHRANE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-E/Cochrane_E/1km173970546302016LCOCHRANE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-F/Cochrane_F/1km174390544702017LCOCHRANE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-G
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-G/Cochrane_G/1km174730542702017LCOCHRANE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-H
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-H/Cochrane_H/1km174970542702017LCOCHRANE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-A/1km173230465902017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-B/1km173610465402017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-C/1km173980467002017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-D/1km173610470902017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-E/1km174010470502017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-F/1km174010473302017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-G
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-G/1km174410470502017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-H
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-H/1km174410473402017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-I
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-I/1km174730473402017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-J
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-J/1km175020472302017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-K
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-K/1km175330471302017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-L
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-L/1km174950476802017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-M
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-M/1km174640476802017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-N
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-N/1km174950477602017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-O
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-O/1km175330474802017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-P
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-P/1km175660473602017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-Q
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-Q/1km175620477602017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-R
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-R/1km175430477602017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-S
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-S/1km175220477602017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-T
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-T/1km175240485902017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-U
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-U/1km174790481202018LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-V
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-V/1km175220481802018LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-W
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-W/1km175430481802018LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-X
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-LkErie-X/1km175620480702017LLAKEERIE.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-A/1km176710487402016LPETERBOROUGH.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-B/1km177060486902016LPETERBOROUGH.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-C/1km177400487602017LPETERBOROUGH.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-D/1km176930490202016LPETERBOROUGH.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-E/1km177390490502017LPETERBOROUGH.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-F/1km177400490702017LPETERBOROUGH.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-G
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-G/1km176850496102016LPETERBOROUGH.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-H
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-H/1km177110493202017LPETERBOROUGH.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-I
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Ptbo-I/1km177290493202017LPETERBOROUGH.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-A/1km173820474802022LLAKEHURON_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-B/1km174150475502022LLAKEHURON_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-C/1km174360475602022LLAKEHURON_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-D/1km174560475502022LLAKEHURON_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-E/1km174230478602022LLAKEHURON_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-F/1km174600478602022LLAKEHURON_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-G
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-G/1km174410481002022LLAKEHURON_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-H
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeHuron-DTM-H/1km174640481002022LLAKEHURON_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-A/1km174920508402020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-B/1km175140509002020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-C/1km175380509302020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-D/1km175540509502020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-E/1km175360512002020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-F/1km175560511202020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-G
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-G/1km175750510602020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-H
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-H/1km175950510702020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-I
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-I/1km176150509302020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-J
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-J/1km176330509502020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-K
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-K/1km176150511002020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-L
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-L/1km176380511702020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-M
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-M/1km176520511402020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-N
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-N/1km176660511302020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-O
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-O/1km175360514202020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-P
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-P/1km175560512902020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-Q
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-Q/1km175760512602020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-R
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-R/1km175940512902020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-S
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-S/1km176150513102020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-T
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-T/1km176150514002020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-U
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-U/1km175220514902020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-V
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeNipissing-DTM-V/1km175520514402020LLAKENIPISSING_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeSimcoe-DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeSimcoe-DTM-A/1km175980491502022LLAKESIMCOE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeSimcoe-DTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeSimcoe-DTM-B/1km176030492002022LLAKESIMCOE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeSimcoe-DTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeSimcoe-DTM-C/1km176330491402022LLAKESIMCOE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/LakeSimcoe-DTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/LakeSimcoe-DTM-D/1km176370489202022LLAKESIMCOE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2018-CGVD2013-DTM
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2018-CGVD2013-DTM/1km175930500502018LMuskoka_CGVD2013_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2018-CGVD28-DTM
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2018-CGVD28-DTM/1km175930500502018LMuskoka_CGVD28_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2021-CGVD2013-DTM
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2021-CGVD2013-DTM/1km175690499402021LMuskoka_CGVD2013_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2021-CGVD28-DTM
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2021-CGVD28-DTM/1km175690499402021LMuskoka_CGVD28_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2023-CGVD2013-DTM-1
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2023-CGVD2013-DTM-1/1km176040497002023LMuskoka_CGVD2013_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2023-CGVD2013-DTM-2
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2023-CGVD2013-DTM-2/1km176140502502023LMuskoka_CGVD2013_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2023-CGVD28-DTM-1
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2023-CGVD28-DTM-1/1km176040497002023LMuskoka_CGVD28_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2023-CGVD28-DTM-2
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Muskoka-2023-CGVD28-DTM-2/1km176140502502023LMuskoka_CGVD28_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-A/1km183970503502020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-B/1km184110504102020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-C/1km184250503402020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-D/1km184350502302020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-E/1km184510503602020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-F/1km183910502802020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-G
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-G/1km184120502002020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-H
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-H/1km184290502002020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-I
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-I/1km184550502002020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-J
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-J/1km184680502002020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-K
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-K/1km184000501902020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-L
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-L/1km184240500102020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-M
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-M/1km184390500102020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-N
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-N/1km184540500402020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-O
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-O/1km184160500002020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-P
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-P/1km184370497902020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-Q
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaGatineau-DTM-Q/1km184540499102020LOTTAWAGATINEAU_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-A/1km18296050560LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-B/1km18319050790LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-C/1km18337050750LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-D
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-D/1km18324050740LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-E
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-E/1km18350050570LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-F
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-F/1km18364050570LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-G
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-G/1km18325050450LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-H
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-H/1km18345050370LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-I
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-I/1km18360050370LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-J
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-J/1km18374050520LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-K
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-K/1km18374050430LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-L
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-L/1km18374050350LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-M
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-M/1km18396050170LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-N
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-N/OttawaRiver-DTM-N/1km18415050610LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-O
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-O/OttawaRiver-DTM-O/1km18410050590LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-P
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-P/1km18441050420LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-Q
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-Q/1km18457050480LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-R
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-R/1km18474050410LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-S
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-S/1km18492050280LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-T
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-T/1km18484050460LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-U
# Found file: /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-U/1km18506050490LOTTAWARIVER_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-01
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-01/1km173430510802023LSAULTSTEMARIE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-02
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-02/1km173650511102023LSAULTSTEMARIE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-03
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-03/1km173820511002023LSAULTSTEMARIE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-04
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-04/1km173990510402023LSAULTSTEMARIE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-05
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-05/1km174130510402023LSAULTSTEMARIE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-06
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-06/1km174250510202023LSAULTSTEMARIE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-07
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-07/1km173400513802023LSAULTSTEMARIE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-08
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-08/1km173570513202023LSAULTSTEMARIE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-09
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SaultSteMarie-DTM-09/1km173730513202023LSAULTSTEMARIE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/SouthNationConservation_DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/SouthNationConservation_DTM-A/1km184440494702018LSNC_DTM.img
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-01
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-01/1km174360511502023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-02
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-02/1km174540512202023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-03
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-03/1km174740512202023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-04
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-04/1km174930512902023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-05
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-05/1km174540514702023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-06
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-06/1km174760514502023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-07
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-07/1km174950514502023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-08
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-08/1km175140514502023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-14
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-14/1km175320518402023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/York-LakeSimcoe-DTM-A
# Found file: /Volumes/Expansion 1/DTM_UNZIP/York-LakeSimcoe-DTM-A/1km175970486702019LLAKESIMCOE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/York-LakeSimcoe-DTM-B
# Found file: /Volumes/Expansion 1/DTM_UNZIP/York-LakeSimcoe-DTM-B/1km176110487902019LLAKESIMCOE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/York-LakeSimcoe-DTM-C
# Found file: /Volumes/Expansion 1/DTM_UNZIP/York-LakeSimcoe-DTM-C/1km176170489402019LLAKESIMCOE_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-09
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-09/1km174630518002023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-10
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-10/1km174780516802023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-11
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-11/1km174930517102023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-12
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-12/1km175080518802023LSUDBURY_DTM.tif
# Checking folder: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-13
# Found file: /Volumes/Expansion 1/DTM_UNZIP/Sudbury-DTM-13/1km175120519002023LSUDBURY_DTM.tif
# Metadata saved to raster_metadata.csv

# %%
import os
from osgeo import gdal, osr

# Define the input directory
input_dir = '/Volumes/Expansion 1/DTM_UNZIP'

# Define the output text file path (saving in current directory)
output_file = 'spatial_reference_info.txt'  # This will be saved in the current directory

# Open the output file in write mode
with open(output_file, 'w') as txt_file:
    # Get a list of all subdirectories in the input directory
    folders = [
        os.path.join(input_dir, d) for d in os.listdir(input_dir)
        if os.path.isdir(os.path.join(input_dir, d))
    ]

    # Iterate over each folder
    for folder in folders:
        # List all files in the current folder
        files = os.listdir(folder)
        # Find the first file that ends with .tif or .img (case-insensitive)
        tif_img_files = [
            f for f in files if f.lower().endswith(('.tif', '.tiff', '.img'))
        ]
        if tif_img_files:
            # Get the first matching file
            first_file = tif_img_files[0]
            filepath = os.path.join(folder, first_file)
            # Open the file using GDAL
            dataset = gdal.Open(filepath)
            if dataset:
                # Get spatial reference information
                projection = dataset.GetProjection()
                geotransform = dataset.GetGeoTransform()
                # Get spatial reference in WKT format
                srs = osr.SpatialReference(wkt=projection)
                wkt = srs.ExportToPrettyWkt()
                # Prepare the content to write to the text file
                content_lines = [
                    f"Folder: {os.path.basename(folder)}",
                    f"File: {first_file}",
                    "\n--- Spatial Reference (WKT) ---\n",
                    wkt,
                    "\n--- GeoTransform ---\n",
                    ', '.join(map(str, geotransform)),
                    "\n" + "="*60 + "\n"  # Separator between entries
                ]
                content = '\n'.join(content_lines)
                # Write the content to the text file
                txt_file.write(content)
                print(f"Appended spatial reference information for {first_file} to {output_file}")
            else:
                print(f"Failed to open {filepath}")
        else:
            print(f"No .tif or .img files found in {folder}")
# Out:
# Appended spatial reference information for 1km182830488802022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183050486602022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183190485802022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183290485602022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km182800489802022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km182700496302022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183010488902022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183190489302022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km182810492602022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183030490902022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183220490902022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183400489302022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km182750494402022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km182980492802022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183180492802022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183380492802022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km182910494602022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183100494602022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km182500498502022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km182700496502022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km182830496502022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183040496502022LBELLEVILLE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176530487602018LCLOCA_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km183330488202022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183700489702022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183520493302022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183820491002022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184100491002021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183330495502021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183650493402022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183900494302022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184250493702022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183130497702021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183480495802022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183710495802022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183950495802022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184220495802022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184500495802022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183150498102021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183450498102021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183620498102021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183800498102022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183800499902021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184020498102022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184360498102022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184670501302021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184960499302021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km185190498302021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184660501602021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km185050504602021LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km185260501302022LEASTERNONTARIO_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175890483602015LBrampton_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175690480902018LHalton_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175920479202018LHalton_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175710481402018LHalton_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175900481402018LHalton_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175620484902017LMilton_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175720485302016LPeel_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175660485902016LPeel_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175840486502014LGTA2014_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176020483902014LGTA2014_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176140484702014LGTA2014_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176300485702014LGTA2014_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175780486802015LGTA2015_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175930483102015LGTA2015_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176130481602015LGTA2015_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176240483102015LGTA2015_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176350483002015LGTA2015_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176470484502015LGTA2015_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175650480502021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175840477802021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176010477302021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176210477302021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176430477302021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175880477002021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176090475502021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176250475802021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176450475802021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176220474402021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176470474702021LNIAGARA_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174400484302022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174640483102022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174860483002022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175010481802022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174410485302022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174650485302022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174880485302022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175110485302022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174390487802022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174670487402022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174900487402022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175130487402022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175320487402022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174500489502022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174760489502022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174980489502022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175180489502022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175390489502022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175570488102022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175570489402022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174600491702022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174930491702022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175170491702022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175440493302022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174690496302022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174900493702022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175780492302022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175960491802022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175590496402022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175890494402022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176040494402022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176180494402022LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174770496902023LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174940495802023LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175240493802023LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175740492002023LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175770490702023LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175800489402023LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175830488002023LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174550499502023LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174380501702023LHURONGEORGIANBAY_DTM.tif to spatial_reference_info.txt
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/HuronShores-DTM-01
# Appended spatial reference information for 1km176560487702023LKAWARTHALAKES_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176760488002023LKAWARTHALAKES_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176610490102023LKAWARTHALAKES_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176830490102023LKAWARTHALAKES_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176490493702023LKAWARTHALAKES_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176780492102023LKAWARTHALAKES_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176410496102023LKAWARTHALAKES_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176590494002023LKAWARTHALAKES_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176720494002023LKAWARTHALAKES_DTM.tif to spatial_reference_info.txt
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-A
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-B
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-C
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-D
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LEAP2009_DTM-E
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-A
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-B
# Appended spatial reference information for 1km173620547902017LCOCHRANE.img to spatial_reference_info.txt
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-D
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-E
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-F
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-G
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/LIDAR2016to18_DTM-Crne-H
# Appended spatial reference information for 1km173230465902017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km173610465402017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km173980467002017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km173610470902017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174010470502017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174010473302017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174410470502017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174410473402017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174730473402017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175020472302017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175330471302017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174950476802017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174640476802017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174950477602017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175330474802017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175660473602017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175620477602017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175430477602017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175220477602017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175240485902017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174790481202018LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175220481802018LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175430481802018LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km175620480702017LLAKEERIE.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176710487402016LPETERBOROUGH.img to spatial_reference_info.txt
# Appended spatial reference information for 1km177060486902016LPETERBOROUGH.img to spatial_reference_info.txt
# Appended spatial reference information for 1km177400487602017LPETERBOROUGH.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176930490202016LPETERBOROUGH.img to spatial_reference_info.txt
# Appended spatial reference information for 1km177390490502017LPETERBOROUGH.img to spatial_reference_info.txt
# Appended spatial reference information for 1km177400490702017LPETERBOROUGH.img to spatial_reference_info.txt
# Appended spatial reference information for 1km176850496102016LPETERBOROUGH.img to spatial_reference_info.txt
# Appended spatial reference information for 1km177110493202017LPETERBOROUGH.img to spatial_reference_info.txt
# Appended spatial reference information for 1km177290493202017LPETERBOROUGH.img to spatial_reference_info.txt
# Appended spatial reference information for 1km173820474802022LLAKEHURON_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174150475502022LLAKEHURON_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174360475602022LLAKEHURON_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174560475502022LLAKEHURON_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174230478602022LLAKEHURON_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174600478602022LLAKEHURON_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174410481002022LLAKEHURON_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174640481002022LLAKEHURON_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174920508402020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175140509002020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175380509302020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175540509502020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175360512002020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175560511202020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175750510602020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175950510702020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176150509302020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176330509502020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176150511002020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176380511702020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176520511402020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176660511302020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175360514202020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175560512902020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175760512602020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175940512902020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176150513102020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176150514002020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175220514902020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175520514402020LLAKENIPISSING_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175980491502022LLAKESIMCOE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176030492002022LLAKESIMCOE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176330491402022LLAKESIMCOE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176370489202022LLAKESIMCOE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175930500502018LMuskoka_CGVD2013_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175930500502018LMuskoka_CGVD28_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175690499402021LMuskoka_CGVD2013_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175690499402021LMuskoka_CGVD28_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176040497002023LMuskoka_CGVD2013_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176140502502023LMuskoka_CGVD2013_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176040497002023LMuskoka_CGVD28_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176140502502023LMuskoka_CGVD28_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183970503502020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184110504102020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184250503402020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184350502302020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184510503602020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km183910502802020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184120502002020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184290502002020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184550502002020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184680502002020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184000501902020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184240500102020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184390500102020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184540500402020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184160500002020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184370497902020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184540499102020LOTTAWAGATINEAU_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18296050560LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18319050790LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18337050750LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18324050740LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18350050570LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18364050570LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18325050450LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18345050370LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18360050370LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18374050520LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18374050430LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18374050350LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18396050170LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-N
# No .tif or .img files found in /Volumes/Expansion 1/DTM_UNZIP/OttawaRiver-DTM-O
# Appended spatial reference information for 1km18441050420LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18457050480LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18474050410LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18492050280LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18484050460LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km18506050490LOTTAWARIVER_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km173430510802023LSAULTSTEMARIE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km173650511102023LSAULTSTEMARIE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km173820511002023LSAULTSTEMARIE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km173990510402023LSAULTSTEMARIE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174130510402023LSAULTSTEMARIE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174250510202023LSAULTSTEMARIE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km173400513802023LSAULTSTEMARIE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km173570513202023LSAULTSTEMARIE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km173730513202023LSAULTSTEMARIE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km184440494702018LSNC_DTM.img to spatial_reference_info.txt
# Appended spatial reference information for 1km174360511502023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174540512202023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174740512202023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174930512902023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174540514702023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174760514502023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174950514502023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175140514502023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175320518402023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175970486702019LLAKESIMCOE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176110487902019LLAKESIMCOE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km176170489402019LLAKESIMCOE_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174630518002023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174780516802023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km174930517102023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175080518802023LSUDBURY_DTM.tif to spatial_reference_info.txt
# Appended spatial reference information for 1km175120519002023LSUDBURY_DTM.tif to spatial_reference_info.txt
