# %%
import os
import glob
from osgeo import gdal

def process_subfolder(input_subfolder, output_subfolder, translate_options=None):
    os.makedirs(output_subfolder, exist_ok=True)
    output_mosaic_path = os.path.join(output_subfolder, "final_output.tif")

    # Check if the output mosaic file already exists
    if os.path.exists(output_mosaic_path):
        print(f"Output mosaic already exists for {input_subfolder}, skipping...")
        return

    input_files = sorted(glob.glob(os.path.join(input_subfolder, "*.tif")))

    if not input_files:
        print(f"No TIFF files found in {input_subfolder}")
        return

    print(f"Processing subfolder: {input_subfolder}")

    # Build VRT for the subfolder
    vrt_path = os.path.join(output_subfolder, "subfolder.vrt")
    gdal.BuildVRT(vrt_path, input_files)

    # Translate VRT to regular TIFF (not COG)
    gdal.Translate(output_mosaic_path, vrt_path, options=translate_options)

    # Clean up VRT
    os.remove(vrt_path)

    print(f"Final mosaic for {input_subfolder} created at: {output_mosaic_path}")

def create_mosaic_from_subfolders(input_root, output_root, test_mode=False):

    gdal.SetConfigOption('GDAL_CACHEMAX', '4096')
    gdal.SetConfigOption('GDAL_NUM_THREADS', 'ALL_CPUS')
    gdal.SetConfigOption('GDAL_MEMORY_LIMIT', '4096')
    # GDAL Translate Options - focus on speed, normal TIFF output
    translate_options = gdal.TranslateOptions(
        format='GTiff',  # Standard GeoTIFF format
        creationOptions=[
            "COMPRESS=LZW",  # Optional compression for speed, you can remove this if compression affects performance
            "BIGTIFF=YES",   # Enable support for large files
            "NUM_THREADS=ALL_CPUS"  # Utilize all available CPUs

        ]
    )

    # Walk through the input directory structure
    for root, dirs, files in os.walk(input_root):
        # Only process directories that contain TIFF files
        tiff_files = [f for f in files if f.lower().endswith('.tif')]
        if tiff_files:
            relative_path = os.path.relpath(root, input_root)
            input_subfolder = root
            output_subfolder = os.path.join(output_root, relative_path)

            # If test_mode is True, limit the number of files
            if test_mode:
                tiff_files = tiff_files[:1000]

            process_subfolder(input_subfolder, output_subfolder, translate_options)

    print("All subfolders processed.")

# %%
if __name__ == "__main__":
    # Replace these paths with your actual paths
    input_root = "/Volumes/Expansion 1/DTM_UNZIP"
    output_root = "/Volumes/Expansion 1/DTM_TIFF"
    test_mode = False  # Set to True to process a smaller subset for testing

    create_mosaic_from_subfolders(input_root, output_root, test_mode)
# Out:
# Processing subfolder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-A
# /Users/b/Documents/GitHub/ontario-dtm/.conda/lib/python3.12/site-packages/osgeo/gdal.py:312: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# Final mosaic for /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-A created at: /Volumes/Expansion 1/DTM_TIFF/Belleville-DTM-A/final_output.tif
# Processing subfolder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-B
# Final mosaic for /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-B created at: /Volumes/Expansion 1/DTM_TIFF/Belleville-DTM-B/final_output.tif
# Processing subfolder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-C
# Final mosaic for /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-C created at: /Volumes/Expansion 1/DTM_TIFF/Belleville-DTM-C/final_output.tif
# Processing subfolder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-D
# Final mosaic for /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-D created at: /Volumes/Expansion 1/DTM_TIFF/Belleville-DTM-D/final_output.tif
# Processing subfolder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-E
# Final mosaic for /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-E created at: /Volumes/Expansion 1/DTM_TIFF/Belleville-DTM-E/final_output.tif
# Processing subfolder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-P
# Final mosaic for /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-P created at: /Volumes/Expansion 1/DTM_TIFF/Belleville-DTM-P/final_output.tif
# Processing subfolder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-F
# Final mosaic for /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-F created at: /Volumes/Expansion 1/DTM_TIFF/Belleville-DTM-F/final_output.tif
# Processing subfolder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-G
# Final mosaic for /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-G created at: /Volumes/Expansion 1/DTM_TIFF/Belleville-DTM-G/final_output.tif
# Processing subfolder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-H

# %%
import os
import subprocess

# Define the root directory containing subfolders with raster tiles
input_dir = "/Volumes/Expansion 1/DTM_UNZIP"

# Function to execute shell commands
def run_gdal_command(cmd):
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print(f"Error: {result.stderr}")
    else:
        print(f"Success: {result.stdout}")

# Process each subfolder in the input directory
for subfolder in os.listdir(input_dir):
    subfolder_path = os.path.join(input_dir, subfolder)
    
    if os.path.isdir(subfolder_path):
        output_mosaic = os.path.join(subfolder_path, "mosaic.tif")

        # Skip if output mosaic already exists
        if os.path.exists(output_mosaic):
            print(f"Skipping {subfolder}: mosaic.tif already exists.")
            continue
        
        print(f"Processing folder: {subfolder_path}")
        
        # Find all TIFF files in the subfolder
        tiff_files = [os.path.join(subfolder_path, f) for f in os.listdir(subfolder_path) if f.endswith(".tif")]

        if tiff_files:
            # Create VRT file
            vrt_file = os.path.join(subfolder_path, "mosaic.vrt")
            vrt_command = f"gdalbuildvrt {vrt_file} {' '.join(tiff_files)}"
            run_gdal_command(vrt_command)

            # Convert VRT to GeoTIFF
            translate_command = f"gdal_translate {vrt_file} {output_mosaic} -co COMPRESS=LZW"
            run_gdal_command(translate_command)

            # Remove VRT after conversion
            os.remove(vrt_file)
        else:
            print(f"No TIFF files found in {subfolder_path}")
# Out:
# Processing folder: /Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-A
# Error: Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/mosaic.vrt. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182830488802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182840488402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182840488502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182840488602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182840488702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182840488802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182850488102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182850488202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182850488302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182850488402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182850488502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182850488602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182850488702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182850488802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860487802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860487902022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860488002022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860488102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860488202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860488302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860488402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860488502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860488602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860488702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182860488802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870487702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870487802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870487902022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870488002022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870488102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870488202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870488302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870488402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870488502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870488602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870488702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182870488802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880487702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880487802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880487902022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880488002022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880488102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880488202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880488302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880488402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880488502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880488602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km182880488702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1
LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183010488302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183010488402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183010488502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183010488602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183010488702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183010488802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020486602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020486702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020486802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020486902022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487002022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020487902022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020488002022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020488102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020488202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020488302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020488402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020488502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020488602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020488702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183020488802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030486602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030486702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030486802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030486902022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487002022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030487902022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030488002022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030488102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030488202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030488302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030488402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030488502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030488602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030488702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183030488802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040486602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040486702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040486802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040486902022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487002022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487802022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040487902022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040488002022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040488102022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040488202022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040488302022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040488402022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040488502022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040488602022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040488702022LBELLEVILLE_DTM.tif. Skipping it
# Warning 1: Can't open /Volumes/Expansion. Skipping it
# Warning 1: Can't open 1/DTM_UNZIP/Belleville-DTM-A/1km183040488802022LBELLEVILLE_DTM.tif. Skipping it
#
# Error: ERROR 1: Maximum number of positional arguments exceeded, failed to parse '/Volumes/Expansion'
# Usage: gdal_translate [--help] [--long-usage] [--help-general]
#                       [-ot Byte|Int8|[U]Int{16|32|64}|CInt{16|32}|[C]Float{32|64}] [-if <format>]...
#                       [-of <output_format>] [--quiet] [-b <band>]... [-mask <mask>] [-expand gray|rgb|rgba]
#                       [[-strict]|[-not_strict]]
#                       [-outsize <xsize[%]|0> <ysize[%]|0>] [-tr <xres> <yes>] [-ovr <level>|AUTO|AUTO-<n>|NONE] [-sds]
#                       [-r nearest,bilinear,cubic,cubicspline,lanczos,average,mode]
#                       [[-scale [<src_min> <src_max> [<dst_min> <dst_max>]]]...|
#                       [-scale_X [<src_min> <src_max> [<dst_min> <dst_max>]]]...|[-unscale]]
#                       [[-exponent <value>]|[-exponent_X <value>]...]
#                       [-srcwin <xoff> <yoff> <xsize> <ysize>] [-projwin <ulx> <uly> <lrx> <lry>]
#                       [-projwin_srs <srs_def>] [-epo] [-eco] [-a_srs <srs_def>] [-a_coord_epoch <epoch>]
#                       [-a_ullr <ulx> <uly> <lrx> <lry>] [-a_nodata <value>|none]
#                       [-a_gt <gt(0)> <gt(1)> <gt(2)> <gt(3)> <gt(4)> <gt(5)>] [-a_scale <value>] [-a_offset <value>]
#                       [-nogcp] [-gcp <pixel> <line> <easting> <northing> [<elevation>]]...
#                       [-colorinterp {red|green|blue|alpha|gray|undefined},...]
#                       [-colorinterp_X {red|green|blue|alpha|gray|undefined}]...
#                       [[-stats]|[-approx_stats]]
#                       [-norat] [-noxmp] [-co <NAME>=<VALUE>]... [-mo <NAME>=<VALUE>]... [-dmo <DOMAIN>:<KEY>=<VALUE>]...
#                       [-oo <NAME>=<VALUE>]...
#                       <input_file> <output_file>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 43
#      40     run_gdal_command(translate_command)
#      42     # Remove VRT after conversion
# ---> 43     os.remove(vrt_file)
#      44 else:
#      45     print(f"No TIFF files found in {subfolder_path}")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/Expansion 1/DTM_UNZIP/Belleville-DTM-A/mosaic.vrt'
